# %% [markdown]
# <a href="https://colab.research.google.com/github/bbcx-investments/notebooks/blob/main/risk/longrunrisk_sim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm

numsims = 20000

# example data
mna = 0.06
sda = 0.2
mnb = 0.06
sdb = 0.1
T = 30

# frozen normal variables
rva = norm(loc=mna,scale=sda)
rvb = norm(loc=mnb,scale=sdb)

# compounded return for each simulation
compounded = None
for rv in [rva,rvb] :
    rets = pd.DataFrame(rv.rvs(T*numsims).reshape((T,numsims)))
    d = (1+rets).prod()
    compounded = pd.concat((compounded,d), axis=1)
compounded.columns = ['return 1','return 2']

# percentiles
percentiles = compounded.quantile([i/100 for i in range(1,100)])
percentiles.index.name = 'percentage'

# mean, stdev, and some percentiles
stats = compounded.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])

# %%
percentiles
# Out:
#              return 1   return 2
# percentage
# 0.01         0.239344   1.433749
# 0.02         0.335473   1.673161
# 0.03         0.413490   1.842134
# 0.04         0.474698   1.979158
# 0.05         0.534848   2.102978
# ...               ...        ...
# 0.95        18.722567  11.615207
# 0.96        20.850534  12.245099
# 0.97        23.497203  13.087240
# 0.98        27.925134  14.370810
# 0.99        35.974501  16.701034
#
# [99 rows x 2 columns]

# %%
stats
# Out:
#            return 1      return 2
# count  20000.000000  20000.000000
# mean       5.766276      5.738196
# std        7.884230      3.171372
# min        0.028224      0.459287
# 10%        0.805736      2.560127
# 25%        1.601634      3.539758
# 50%        3.369649      5.055652
# 75%        6.866898      7.140453
# 90%       13.006442      9.724283
# max      161.675654     44.291912
